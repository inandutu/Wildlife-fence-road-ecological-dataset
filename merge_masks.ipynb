# %%
import tensorflow as tf
import os
from PIL import Image
import numpy as np
# Out:
# 2022-06-24 22:25:31.600859: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-24 22:25:31.601244: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
imagesi = os.listdir('./images') ## This is a list
images = ('./images') ##This is a path.

# %% [markdown]
# ##Image concatenation to create mask

# %%
## That function takes the different images in the folder mask obtaining from the json code and convert it into one single image
def Adding_masks( list_images):
  masks_to_imgs =[]
  for img_ in list_images:
    masks_to_imgs.append(tf.keras.utils.img_to_array(Image.open(images + '/' + i + '/' + 'masks/' + img_), data_format=None, dtype=None))
  
  return tf.keras.utils.array_to_img(sum(masks_to_imgs))

# %%
## That code is used to take the different images obtaining from the above code and save it another subdirectory with the extension .png.
Ii = []
mas = []
for i in imagesi:
    Ima = os.listdir(images + '/' + i + '/' + 'masks')
    mas_1 = Adding_masks(Ima)
    os.chdir('./target_masks') #the new direcrory
    mas_1.save(i +'.png')
    Ii.append(mas_1)

# %% [markdown]
# ## Image extraction

# %%
## That code returns the different images used for annotation, so it is the original one.
def list_img(list_images):   
    imgs =[]
    for img_ in list_images:
        imgs.append(Image.open(images + '/' + i + '/' + 'images/' + img_))
        return(imgs)

# %%
#Different images extracted and saved under another extension 'jpegp'. 
j=1
for i in imagesi:
  Ima = os.listdir(images + '/' + i + '/' + 'images') 
  ma_1 = list_img(Ima)
  
  for img in ma_1:
    os.chdir('./input_images') #The new directory
    #img.save(Ima[0])  ### Position zero 
    img.save(str(i) + '.png')
    j=j+1
